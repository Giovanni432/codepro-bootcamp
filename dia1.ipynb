# %%
print('hola mundo')
# Out:
# hola mundo

# %%
#snake_case:
frase_famosa = 'hola mundo'

#orden de ejecucion:
fruta = 'naranja'
print(fruta)

cantidad_de_frutas = 4
print(cantidad_de_frutas)

fruta = 'banana'
print (fruta)
# Out:
# naranja
# 4
# banana

# %%
edad = 28 #--> intenger
altura = 1.80 # --> float
nombre = 'maggi' # --> string
feliz = True #bool 

print(nombre)
print(edad)
print(altura)
print(feliz)
# Out:
# maggi
# 28
# 1.8
# True

# %%
nombre = "Giovanni" # para lo que vaya de la variante ""
edad = 18 # algun numero sin esa necesidad de usar las comillas queriendo usar en operaciones matematicas
ciudad = 'asuncion' # lo mismo aqui al ser un nombre

print(nombre, edad, ciudad) # print todo en uno pero usando (,)
# Out:
# Giovanni 18 asuncion

# %%
producto1 = 'papas fritas'
costo_producto1 = 15000
producto2 = 'coca cola'
costo_producto2 = 14000
capital = 50000
dolar = 6700

# sumas

costo_total = costo_producto1 + costo_producto2 
print(costo_total)

vuelto = capital - costo_total
print(vuelto)

# realizamos division 

vuelto_dolar = vuelto/dolar
print(vuelto_dolar )
# Out:
# 29000
# 21000

# %%
#challenge 2
#momento de suma
cantidad_de_manzanas = 16
cantidad_de_naranjas = 12
print(cantidad_de_manzanas,cantidad_de_naranjas)

cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas

print(cantidad_de_frutas)

#aclaracion de frutas vendidas y frutas restantes
frutas_vendidas = 8
print(frutas_vendidas)

#momento de resta
frutas_restantes = cantidad_de_frutas - frutas_vendidas

print(frutas_restantes)
# Out:
# 16 12
# 28
# 8
# 20

# %%
#Concatenar los strings

#print (nombres + ' ' + apellido) (o tambien la palabra espacio)

# %%
#challenge 3

#asignar nombre y apellido
nombre = "Hugo"
apellido = "Barboza" 

#imprimir
print(f'hola me llamo {nombre} {apellido}, mucho gusto :)')
# Out:
# hola me llamo Hugo Barboza, mucho gusto :)

# %%
nombre = input('escribe tu nombre')
print(nombre)
# Out:
# Giovanni

# %%
# solicitar el producto
producto = input('que producto desea')
print(producto)

#solicitar que cantidad quiere
cantidad_de_producto = input('que cantidad de producto deseas')
print(cantidad_de_producto)

print(f'el cumpleanero quiere una {producto} en {cantidad_de_producto} porciones')
# Out:
# torta
# 4
# el cumpleanero quiere una torta en 4 porciones

# %%
cantidad_de_autos = int(input('cuantos autos tiene el usuario'))
cantidad_de_casas = int(input('cuantas casas tiene el usuario'))

total_de_items = cantidad_de_autos + cantidad_de_casas
print(f'entre terrenos y vehiculos tiene un total de {total_de_items} pertenecias.')
# Out:
# entre terrenos y vehiculos tiene un total de 10 pertenecias.

# %%
#se define la funcion
def preparar_sandwich():
    print('preparar un sandwich')
    print('ya el sandwich esta casi listo')
    #termino de la funcion
#llamar a la funcion
preparar_sandwich()
# Out:
# preparar un sandwich
# ya el sandwich esta casi listo

# %%
def arrancar_el_auto():
    print('intentar el primer arranque')
    print('intentar el segundo arranque')
    print('motor encendido correctamente')
arrancar_el_auto()
arrancar_el_auto()
arrancar_el_auto()
# Out:
# intentar el primer arranque
# intentar el segundo arranque
# motor encendido correctamente
# intentar el primer arranque
# intentar el segundo arranque
# motor encendido correctamente
# intentar el primer arranque
# intentar el segundo arranque
# motor encendido correctamente

# %%
def televisor(pantalla_OLED,pantalla_tactil,control_con_carga):
    print(f'que tipo de pantalla seria? {pantalla_OLED}')
    print(f'esta tele como seria su pantalla? {pantalla_tactil}')
    print(f'es un control a pila? {control_con_carga}')

funcion1 = 'seria OLED'
funcion2 = 'es Tactil'
funcion3 = 'si es un control a carga'
televisor(funcion1,funcion2,funcion3)
# Out:
# que tipo de pantalla seria? seria OLED
# esta tele como seria su pantalla? es Tactil
# es un control a pila? si es un control a carga

# %%
def cama(tamanho,color,precio)
    print('especifique que tamanho quiere {tamanho}')
    print('especifique el color {color}')
    print('que precio esta dispuesto a pagar {precio}')
especificacion1 =  
especificacion2 = 
especificacion3 =
# Out:
#   Cell In[72], line 1
#     def cama(tamanho,color,precio)
#                                   ^
# SyntaxError: expected ':'
