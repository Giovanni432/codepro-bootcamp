# %%
print('hola')
# Out:
# hola

# %%
#poner la variable junto con la palabra (palabra)

palabra = 'hola'

def imprimir_palabra():
    print(palabra)

imprimir_palabra()
# Out:
# hola

# %%
letra1 = 'l1'
letra2 = 'l2'
def verificar_letra(l1,l2):
    print(letra1)
    print(letra2)

if letra1 == letra2:
    print('las letras son iguales')
else:
    print('las letras son diferentes')
# Out:
# las letras son diferentes

# %%
def retirar_dinero(dinero):
    return f'retirando{dinero}'
dinero_retirado = retirar_dinero(50000)

# %%
def coincidencia_numeros(palabra, numero):
    contar_palabra = len(palabra)
    if contar_palabra == numero:
        coincidencia = True
        print(coincidencia)
    else:
        coincidencia = False

# %%
def revision_de_palabra(computadora):
    eleccion_de_palabra = 'computadora'
    if eleccion_de_palabra == computadora:
        return [computadora]

# %%
palabra_inicial = input('ingrese su palabra')
print(palabra_inicial)
lista = list(palabra_inicial)
for i in range(3):
    print(lista)
# Out:
# hla
# ['h', 'l', 'a']
# ['h', 'l', 'a']
# ['h', 'l', 'a']

# %%
lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
def funcion():
    for i in range(3):
        print(lista[i])
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']
